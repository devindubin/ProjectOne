# %%
# Dependencies and Setup
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# %%
# Employment by Industry files
Industry_19692001_path = "Lesly_Resources/SAEMP25S__ALL_AREAS_1969_2001.csv"
Industry_19982019_path = "Lesly_Resources/SAEMP25N__ALL_AREAS_1998_2019.csv"
# Read csv files
Industry_19692001 = pd.read_csv(Industry_19692001_path)
Industry_19982019 = pd.read_csv(Industry_19982019_path)

# %%
Industry_19692001.head()
# Out:
#     GeoFIPS        GeoName Region TableName  LineCode IndustryClassification  \
# 0   "00000"  United States         SAEMP25S      10.0                    ...
# 1   "00000"  United States         SAEMP25S      20.0                    ...
# 2   "00000"  United States         SAEMP25S      40.0                    ...
# 3   "00000"  United States         SAEMP25S      50.0                    ...
# 4   "00000"  United States         SAEMP25S      60.0                    ...
#
#                            Description            Unit      1969      1970  \
# 0    Total employment (number of jobs)  Number of jobs  91053200  91277600
# 1           Wage and salary employment  Number of jobs  78722000  78793000
# 2               Proprietors employment  Number of jobs  12331200  12484600
# 3          Farm proprietors employment  Number of jobs   2751000   2717000
# 4    Nonfarm proprietors employment 2/  Number of jobs   9580200   9767600
#
# ...

# %%
Industry_19982019.head()
# Out:
#     GeoFIPS        GeoName Region TableName  LineCode IndustryClassification  \
# 0   "00000"  United States         SAEMP25N      10.0                    ...
# 1   "00000"  United States         SAEMP25N      20.0                    ...
# 2   "00000"  United States         SAEMP25N      40.0                    ...
# 3   "00000"  United States         SAEMP25N      50.0                    ...
# 4   "00000"  United States         SAEMP25N      60.0                    ...
#
#                            Description            Unit       1998       1999  \
# 0    Total employment (number of jobs)  Number of jobs  158481200  161531300
# 1           Wage and salary employment  Number of jobs  131920000  134766000
# 2               Proprietors employment  Number of jobs   26561200   26765300
# 3          Farm proprietors employment  Number of jobs    2249000    2237000
# 4    Nonfarm proprietors employment 2/  Number of jobs   24312200   24528300
#
# ...

# %%
# Combine the data into a single dataset
combined_data = pd.merge(Industry_19692001, Industry_19982019, on="LineCode", how='outer')

# %%
combined_data
# Out:
#       GeoFIPS_x      GeoName_x Region_x TableName_x  LineCode  \
# 0       "00000"  United States             SAEMP25S      10.0
# 1       "00000"  United States             SAEMP25S      10.0
# 2       "00000"  United States             SAEMP25S      10.0
# 3       "00000"  United States             SAEMP25S      10.0
# 4       "00000"  United States             SAEMP25S      10.0
# ...         ...            ...      ...         ...       ...
# 86171       NaN            NaN      NaN         NaN    2012.0
# 86172       NaN            NaN      NaN         NaN    2012.0
# 86173       NaN            NaN      NaN         NaN    2012.0
# 86174       NaN            NaN      NaN         NaN    2012.0
# 86175       NaN            NaN      NaN         NaN    2012.0
#
#       IndustryClassification_x                      Description_x  \
# 0                          ...  Total employment (number of jobs)
# 1                          ...  Total employment (number of jobs)
# ...
