# %%
# Dependencies and Setup
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %% [markdown]
# # (1) Minimum Wage Data (mini_wage_df)
#
# * https://www.kaggle.com/lislejoem/us-minimum-wage-by-state-from-1968-to-2017
# * https://www.dol.gov/agencies/whd/state/minimum-wage/history

# %%
mini_wage_path = "mini_wage_data.csv"
mini_wage_df = pd.read_csv(mini_wage_path,encoding='iso-8859-1')
mini_wage_df = mini_wage_df.reset_index(drop=True)
# min_wage_df

# %%
mini_wage_df[mini_wage_df['State']=='Alabama'].head()
# Out:
#      ï»¿  Year    State Table_Data Footnote  High.Value  Low.Value  \
# 0      0  1968  Alabama        ...      NaN         0.0        0.0
# 55    55  1969  Alabama        ...      NaN         0.0        0.0
# 110  110  1970  Alabama        ...      NaN         0.0        0.0
# 165  165  1971  Alabama        ...      NaN         0.0        0.0
# 220  220  1972  Alabama        ...      NaN         0.0        0.0
#
#      CPI.Average  High.2018  Low.2018
# 0      34.783333        0.0       0.0
# 55     36.683333        0.0       0.0
# 110    38.825000        0.0       0.0
# 165    40.491667        0.0       0.0
# 220    41.816667        0.0       0.0

# %% [markdown]
# # (2) LABOR FORCE (labor_force_df)
# ## Combining State by State Labor Force Data
# * Year [1976-2020]
# * Period [Jan - Dec]
# * labor force participation rate
# * employment-population ratio
# * labor force	employment
# * unemployment
# * unemployment rate
#
# * references : https://www.bls.gov/lau/

# %% [markdown]
# The values in the dataset are as follows:
# * Year: The year of the data.
# * State: The state or territory of the data.
# * Table_Data: The scraped value from the source.
# * Footnote: The footnote associated with the Table_Data. See more below in the dataset description. You can alternatively find them at the bottom of the US Department of Labor's page.
# * High.Value: As there were some values in Table_Data that had multiple values (usually associated with footnotes), this is the higher of the two values in the table. It could be useful for viewing the proposed minimum wage, because in most cases, the higher value meant that all persons protected under minimum wage laws eventually had minimum wage set at that value.
# * Low.Value: This is the same as High.Value, but has the lower of the two values. This could be useful for viewing the effective minimum wage at the year of setting the minimum wage, as peoples protected under such minimum wage laws made that value during that year (although, in most cases, they had a higher minimum wage after that year).
# * CPI.Average: This is the Consumer Price Index associated with that year. It was used to calculate 2018-equivalent values.
# * High.2018: This is the 2018-equivalent dollars for High.Value.
# * Low.2018: This is the 2018-equivalent dollars for Low.Value.

# %% [markdown]
# #### Generate DataFrame

# %%
# Generate Each CSV file into saperate DataFrames
state_name = pd.read_csv("STATEWISE DATA LABOR FORCE/state_name.csv")
state_name = state_name[['States', 'st']]

# %%
# list of state
states_list = list(state_name.States)
st_list= list(state_name.st)

# %%
# read csv data of each state and create DataFrame
# Add columns State and St
for state, st in zip(states_list,st_list):
    #print (state, st)
    exec(f"df_{st} = pd.read_csv('STATEWISE DATA LABOR FORCE/{state}.csv')")
    exec(f"df_{st}['states'] = '{state}' ")
    exec(f"df_{st}['st'] = '{st}' ")
    # change all column name to lower case
    exec(f"df_{st}.columns = map(str.lower, df_{st}.columns)")

# %% [markdown]
# #### Combine DataFrame

# %%
com_labor_df = pd.DataFrame()
for st in st_list:
    com_labor_df = pd.concat([com_labor_df, eval(f"df_{st}")])

# %%
com_labor_df.head(55)
# Out:
#     year period  labor force participation rate employment-population ratio  \
# 0   1976    Jan                            57.3                        53.4
# 1   1976    Feb                            57.2                        53.3
# 2   1976    Mar                            57.0                        53.2
# 3   1976    Apr                            56.9                        53.2
# 4   1976    May                            56.8                        53.1
# 5   1976    Jun                            56.8                        53.1
# 6   1976    Jul                            56.8                        53.1
# 7   1976    Aug                            56.9                          53
# 8   1976    Sep                            57.0                        53.1
# 9   1976    Oct                            57.1                        53.1
# 10  1976    Nov                            57.2                        53.1
# 11  1976    Dec                            57.4                        53.2
# 12  1977    Jan                            57.6                        53.3
# 13  1977    Feb                            57.9                        53.4
# 14  1977    Mar                            58.1                        53.6
# 15  1977    Apr                            58.4                        53.8
# 16  1977    May                            58.5                        53.9
# 17  1977    Jun                            58.6                        54.1
# 18  1977    Jul                            58.6                        54.2
# 19  1977    Aug                            58.5                        54.3
# 20  1977    Sep                            58.5                        54.4
# 21  1977    Oct                            58.5                        54.5
# 22  1977    Nov                            58.5                        54.6
# 23  1977    Dec                            58.5                        54.6
# 24  1978    Jan                            58.5                        54.7
# 25  1978    Feb                            58.5                        54.8
# 26  1978    Mar                            58.6                          55
# 27  1978    Apr                            58.7                        55.2
# 28  1978    May                            58.9                        55.3
# 29  1978    Jun                            59.1                        55.5
# 30  1978    Jul                            59.2                        55.6
# 31  1978    Aug                            59.3                        55.6
# 32  1978    Sep                            59.4                        55.6
# 33  1978    Oct                            59.5                        55.6
# 34  1978    Nov                            59.5                        55.5
# 35  1978    Dec                            59.5                        55.5
# 36  1979    Jan                            59.5                        55.4
# 37  1979    Feb                            59.4                        55.3
# 38  1979    Mar                            59.4                        55.2
# 39  1979    Apr                            59.4                        55.1
# 40  1979    May                            59.3                          55
# 41  1979    Jun                            59.3                          55
# 42  1979    Jul                            59.3                          55
# 43  1979    Aug                            59.3                          55
# 44  1979    Sep                            59.3                          55
# 45  1979    Oct                            59.3                        55.1
# 46  1979    Nov                            59.3                        55.1
# 47  1979    Dec                            59.3                          55
# 48  1980    Jan                            59.3                        54.9
# 49  1980    Feb                            59.2                        54.8
# 50  1980    Mar                            59.1                        54.5
# 51  1980    Apr                            59.1                        54.2
# 52  1980    May                            59.0                        53.8
# 53  1980    Jun                            59.0                        53.5
# 54  1980    Jul                            58.9                        53.3
#
#    labor force employment unemployment unemployment rate   states  st
# 0      1492409    1392154       100255               6.7  Alabama  al
# 1      1491820    1391975        99845               6.7  Alabama  al
# 2      1490600    1392137        98463               6.6  Alabama  al
# 3      1489947    1393177        96770               6.5  Alabama  al
# 4      1490609    1394591        96018               6.4  Alabama  al
# 5      1493270    1396510        96760               6.5  Alabama  al
# 6      1497488    1398508        98980               6.6  Alabama  al
# 7      1502397    1400824       101573               6.8  Alabama  al
# 8      1507195    1403488       103707               6.9  Alabama  al
# 9      1512273    1406391       105882                 7  Alabama  al
# 10     1518265    1409707       108558               7.2  Alabama  al
# 11     1525568    1413734       111834               7.3  Alabama  al
# 12     1534383    1418860       115523               7.5  Alabama  al
# 13     1544075    1425097       118978               7.7  Alabama  al
# 14     1553665    1432080       121585               7.8  Alabama  al
# 15     1562297    1439468       122829               7.9  Alabama  al
# 16     1568937    1446727       122210               7.8  Alabama  al
# 17     1573270    1453467       119803               7.6  Alabama  al
# 18     1575689    1459495       116194               7.4  Alabama  al
# 19     1577504    1464868       112636               7.1  Alabama  al
# 20     1579545    1469855       109690               6.9  Alabama  al
# 21     1581808    1474532       107276               6.8  Alabama  al
# 22     1584502    1478914       105588               6.7  Alabama  al
# 23     1587522    1483160       104362               6.6  Alabama  al
# 24     1590947    1487808       103139               6.5  Alabama  al
# 25     1595067    1493428       101639               6.4  Alabama  al
# 26     1600048    1500232        99816               6.2  Alabama  al
# 27     1606042    1507853        98189               6.1  Alabama  al
# 28     1613055    1515549        97506                 6  Alabama  al
# 29     1620381    1522416        97965                 6  Alabama  al
# 30     1627399    1527689        99710               6.1  Alabama  al
# 31     1633399    1531117       102282               6.3  Alabama  al
# 32     1637866    1532949       104917               6.4  Alabama  al
# 33     1641178    1533922       107256               6.5  Alabama  al
# 34     1643767    1534609       109158               6.6  Alabama  al
# 35     1645893    1535097       110796               6.7  Alabama  al
# 36     1647812    1535258       112554               6.8  Alabama  al
# 37     1649538    1534963       114575               6.9  Alabama  al
# 38     1650980    1534270       116710               7.1  Alabama  al
# 39     1652094    1533457       118637               7.2  Alabama  al
# 40     1653228    1533152       120076               7.3  Alabama  al
# 41     1654719    1533709       121010               7.3  Alabama  al
# 42     1656477    1535256       121221               7.3  Alabama  al
# 43     1658553    1537606       120947               7.3  Alabama  al
# 44     1661023    1540377       120646               7.3  Alabama  al
# 45     1663350    1543103       120247               7.2  Alabama  al
# 46     1664951    1545207       119744               7.2  Alabama  al
# 47     1666044    1546087       119957               7.2  Alabama  al
# 48     1666594    1545102       121492               7.3  Alabama  al
# 49     1666602    1541785       124817               7.5  Alabama  al
# 50     1666667    1536128       130539               7.8  Alabama  al
# 51     1666794    1528732       138062               8.3  Alabama  al
# 52     1666872    1520782       146090               8.8  Alabama  al
# 53     1667196    1513892       153304               9.2  Alabama  al
# 54     1667937    1509355       158582               9.5  Alabama  al

# %%
# copy dataFrame
com_labor_df1 = com_labor_df.copy()

# %%
com_labor_df1['employment-population ratio']=com_labor_df1['employment-population ratio'].replace('54.4(P)',54.4)
com_labor_df1['labor force'] = com_labor_df1['labor force'].replace('1079960(V)', 1079960)
com_labor_df1['labor force'] = com_labor_df1['labor force'].replace('-(N)', 'nan')
com_labor_df1['employment'] = com_labor_df1['employment'].replace('964344(V)',964344)
com_labor_df1['employment'] = com_labor_df1['employment'].replace('-(N)', 'nan')
com_labor_df1['unemployment'] = com_labor_df1['unemployment'].replace('115616(V)',115616)
com_labor_df1['unemployment'] = com_labor_df1['unemployment'].replace('-(N)', 'nan')
com_labor_df1['unemployment rate'] = com_labor_df1['unemployment rate'].replace('10.7(V)',10.7)
com_labor_df1['unemployment rate'] = com_labor_df1['unemployment rate'].replace('-(N)', 'nan')

# %%
com_labor_df1.head()
# Out:
#    year period  labor force participation rate employment-population ratio  \
# 0  1976    Jan                            57.3                        53.4
# 1  1976    Feb                            57.2                        53.3
# 2  1976    Mar                            57.0                        53.2
# 3  1976    Apr                            56.9                        53.2
# 4  1976    May                            56.8                        53.1
#
#   labor force employment unemployment unemployment rate   states  st
# 0     1492409    1392154       100255               6.7  Alabama  al
# 1     1491820    1391975        99845               6.7  Alabama  al
# 2     1490600    1392137        98463               6.6  Alabama  al
# 3     1489947    1393177        96770               6.5  Alabama  al
# 4     1490609    1394591        96018               6.4  Alabama  al

# %%
# conver colum to float
# com_labor_df1 = com_labor_df.copy()
com_labor_df1['year'] = com_labor_df1['year'].astype(int)
com_labor_df1['labor force participation rate'] = com_labor_df1['labor force participation rate'].astype(float)
# com_labor_df1['employment-population ratio'] = com_labor_df1['employment-population ratio'].astype(float)
com_labor_df1['employment-population ratio'] = pd.to_numeric(com_labor_df1['employment-population ratio'])
com_labor_df1['labor force'] = com_labor_df1['labor force'].astype(float)
com_labor_df1['employment'] = com_labor_df1['employment'].astype(float)
com_labor_df1['unemployment'] = com_labor_df1['unemployment'].astype(float)
com_labor_df1['unemployment rate'] = com_labor_df1['unemployment rate'].astype(float)

# %%
com_labor_cl_df = com_labor_df1.groupby(['states','st','year'],as_index=False)

# %%
labor_force_df=com_labor_cl_df.mean()
labor_force_df=labor_force_df.reset_index(drop=True)

# %%
labor_force_df.head()
# Out:
#     states  st  year  labor force participation rate  \
# 0  Alabama  al  1976                       57.033333
# 1  Alabama  al  1977                       58.350000
# 2  Alabama  al  1978                       59.058333
# 3  Alabama  al  1979                       59.341667
# 4  Alabama  al  1980                       59.008333
#
#    employment-population ratio   labor force    employment   unemployment  \
# 0                    53.158333  1.500987e+06  1.399433e+06  101553.750000
# 1                    54.058333  1.568600e+06  1.453877e+06  114722.833333
# 2                    55.325000  1.621254e+06  1.518556e+06  102697.750000
# 3                    55.100000  1.656564e+06  1.537704e+06  118860.333333
# 4                    53.766667  1.669343e+06  1.521131e+06  148212.250000
#
#    unemployment rate
# 0           6.766667
# 1           7.316667
# 2           6.316667
# 3           7.175000
# 4           8.883333

# %% [markdown]
# # By year by State Data with Hourly Rate and Anual Rate (employment_df)
# ###### Reference:
# * https://www.bls.gov/oes/tables.htm

# %%
years = range(1997,2020)
for year in years:
    # Generate Each CSV file into saperate DataFrames
    exec(f"df_{year} = pd.read_csv('ToCombine/{year}.csv')")
    # change columns to lower case
    exec(f"df_{year}.columns = map(str.lower, df_{year}.columns)")
    # rename occ_titl to occ_title
    exec(f"df_{year} = df_{year}.rename(columns={{'occ_titl': 'occ_title'}})")
    exec(f"df_{year} = df_{year}.rename(columns={{'year ': 'year'}})")
    exec(f"df_{year} = df_{year}.rename(columns={{'area_title': 'state'}})")  
    #add year column to dataframe
    exec(f"df_{year}['year']={year}")

# %%
# column list to select from each DataFrame
col_list = ['area', 'state', 'occ_code', 
            'occ_title', 'tot_emp', 'h_mean', 
            'a_mean', 'h_median','a_median','annual', 'year']

# %%
# create new clean DataFrame
for year in years:
    exec(f"df_{year}_clean = df_{year}[{col_list}]")

# %% [markdown]
# ##### combine DataFrames

# %%
combine_df = pd.DataFrame()
for year in years :
    combine_df = pd.concat([combine_df, eval(f"df_{year}_clean")])
combine_df.head()
# Out:
#    area    state occ_code                                          occ_title  \
# 0   1.0  Alabama    10000          Managerial and Administrative Occupations
# 1   1.0  Alabama    13000  Staff and Administrative Specialty Managerial ...
# 2   1.0  Alabama    13002                                 Financial Managers
# 3   1.0  Alabama    13005  Personnel, Training, and Labor Relations Managers
# 4   1.0  Alabama    13008                                Purchasing Managers
#
#   tot_emp h_mean a_mean h_median a_median annual  year
# 0     NaN    NaN    NaN      NaN      NaN    NaN  1997
# 1      **  18.04  37530    16.25    33800    NaN  1997
# 2    8140  24.23  50400    20.97    43618    NaN  1997
# 3    2760  20.84  43350    19.29    40123    NaN  1997
# 4    2370  19.07  39660    15.99    33259    NaN  1997

# %% [markdown]
# ##### Cleanup DataFrames

# %%
# drop all in year and tot_emp
combine_df_clean = combine_df.copy()
combine_df_clean = combine_df_clean.dropna(subset=['year', 'tot_emp'])

# %%
temp = combine_df_clean.copy()
# Remove undefine Value
temp = temp[temp['tot_emp'] !='**']
temp = temp[temp['tot_emp'] !='*']
temp = temp[temp['h_mean'] !='*']
temp = temp[temp['h_mean'] !='#']
temp = temp[temp['a_mean'] !='*']
temp = temp[temp['a_mean'] !='#']

# %% [markdown]
# ##### Convert column to float

# %%
temp1= temp.copy()

# %%
temp1['tot_emp']=temp1['tot_emp'].str.replace(',','')
temp1['h_mean']=temp1['h_mean'].str.replace(',','')
temp1['a_mean']=temp1['a_mean'].str.replace(',','')
# temp1['year']=temp1['year'].str.replace(',','')

# %%
temp1['tot_emp']=temp1['tot_emp'].astype(float)
temp1['h_mean']=temp1['h_mean'].astype(float)
temp1['a_mean']=temp1['a_mean'].astype(float)
temp1['year']=temp1['year'].astype(float)

# %%
# employment data
employment_df = temp1.reset_index(drop=True)

# %% [markdown]
# # Data Virtualization

# %%
# copy data from the 3 DataFrames
wage_df = mini_wage_df.copy()
lab_df = labor_force_df.copy()
emp_profile_df = employment_df.copy()

# %%
# STATES OF INTEREST
state_interest = ['California','New York','Alabama','Texas','Arizona','Illinois']

# %%
wage_df.head()
# Out:
#    ï»¿  Year       State           Table_Data Footnote  High.Value  Low.Value  \
# 0    0  1968     Alabama                  ...      NaN     0.00000    0.00000
# 1    1  1968      Alaska                 2.10      NaN     2.10000    2.10000
# 2    2  1968     Arizona  18.72 - 26.40/wk(b)      (b)     0.66000    0.46800
# 3    3  1968    Arkansas          1.25/day(b)      (b)     0.15625    0.15625
# 4    4  1968  California              1.65(b)      (b)     1.65000    1.65000
#
#    CPI.Average  High.2018  Low.2018
# 0    34.783333       0.00      0.00
# 1    34.783333      15.12     15.12
# 2    34.783333       4.75      3.37
# 3    34.783333       1.12      1.12
# 4    34.783333      11.88     11.88

# %%
lab_df.head()
# Out:
#     states  st  year  labor force participation rate  \
# 0  Alabama  al  1976                       57.033333
# 1  Alabama  al  1977                       58.350000
# 2  Alabama  al  1978                       59.058333
# 3  Alabama  al  1979                       59.341667
# 4  Alabama  al  1980                       59.008333
#
#    employment-population ratio   labor force    employment   unemployment  \
# 0                    53.158333  1.500987e+06  1.399433e+06  101553.750000
# 1                    54.058333  1.568600e+06  1.453877e+06  114722.833333
# 2                    55.325000  1.621254e+06  1.518556e+06  102697.750000
# 3                    55.100000  1.656564e+06  1.537704e+06  118860.333333
# 4                    53.766667  1.669343e+06  1.521131e+06  148212.250000
#
#    unemployment rate
# 0           6.766667
# 1           7.316667
# 2           6.316667
# 3           7.175000
# 4           8.883333

# %% [markdown]
# state_interest = ['California','New York','Alabama','Texas','Arizona','Illinois']

# %%
state = state_interest[1]
df1=wage_df[wage_df['State'] == state]
df2=lab_df[lab_df['states'] == state]

fig1, ax1 = plt.subplots(figsize=(8,5))
ax1.scatter(df1['Year'], df1['High.Value'], marker='.', label="Minimum Wage ($)");
ax1.plot(df2['year'], df2['unemployment rate'],color='y', label="Unemployment Rate (%)");
# ax1.scatter(df1['Year'], (df1['CPI.Average']/df1['High.Value'])/4, marker='.');
ax1.scatter(df1['Year'], df1['High.Value']/df1['High.2018'], marker='.', label="Inflation Rate (%)");
ax1.legend();
ax1.set(title=f'{state}',
        xlabel='Year',
       );

# %% [markdown]
# #### WAGE BINS

# %%
# define bin
emp_pro = emp_profile_df.copy()
bin_range = np.arange(round(emp_pro['h_mean'].min()-5,0), round(emp_pro['h_mean'].max()+5,0),5)
bin_name = ['0-5','5-10','10-15','15-20', '20-25','25-30','30-35','35-40',
            '40-45', '45-50', '50-55', '55-60', '60-65', '65-70', '70-75',
            '75-80', '80-85', '85-90', '90-95', '95-100', '100-105', '105-110',
            '110-115', '115-120', '120-125', '125-130', '130-135', '135-140',
           '140-145']

# %%
# employment profile
emp_pro['wage_bin'] = pd.cut(emp_pro['h_mean'], bins=bin_range, labels=bin_name)

# %%
emp_pro.head()
# Out:
#    area    state occ_code                                          occ_title  \
# 0   1.0  Alabama    13002                                 Financial Managers
# 1   1.0  Alabama    13005  Personnel, Training, and Labor Relations Managers
# 2   1.0  Alabama    13008                                Purchasing Managers
# 3   1.0  Alabama    13011  Marketing, Advertising, and Public Relations M...
# 4   1.0  Alabama    13014                   Administrative Services Managers
#
#    tot_emp  h_mean   a_mean h_median a_median annual    year wage_bin
# 0   8140.0   24.23  50400.0    20.97    43618    NaN  1997.0    20-25
# 1   2760.0   20.84  43350.0    19.29    40123    NaN  1997.0    20-25
# 2   2370.0   19.07  39660.0    15.99    33259    NaN  1997.0    15-20
# 3   4500.0   23.76  49420.0    21.52    44762    NaN  1997.0    20-25
# 4   2950.0   20.98  43650.0    19.32    40186    NaN  1997.0    20-25

# %%
temp_emp_pro_bin = emp_pro.copy()
temp_emp_pro_bin = temp_emp_pro_bin.groupby(['state', 'wage_bin', 'year'])

# %%
temp_emp_pro_bin.head()
# Out:
#         area           state occ_code  \
# 0        1.0         Alabama    13002
# 1        1.0         Alabama    13005
# 2        1.0         Alabama    13008
# 3        1.0         Alabama    13011
# 4        1.0         Alabama    13014
# ...      ...             ...      ...
# 721644  78.0  Virgin Islands  31-0000
# 721645  78.0  Virgin Islands  31-1120
# 721646  78.0  Virgin Islands  31-1131
# 721651  78.0  Virgin Islands  33-9032
# 721653  78.0  Virgin Islands  35-0000
#
#                                                 occ_title  tot_emp  h_mean  \
# 0                                      Financial Managers   8140.0   24.23
# 1       Personnel, Training, and Labor Relations Managers   2760.0   20.84
# 2                                     Purchasing Managers   2370.0   19.07
# 3       Marketing, Advertising, and Public Relations M...   4500.0   23.76
# 4                        Administrative Services Managers   2950.0   20.98
# ...                                                   ...      ...     ...
# 721644                     Healthcare Support Occupations    620.0   14.53
# 721645                Home Health and Personal Care Aides    200.0   12.14
# 721646                                 Nursing Assistants    130.0   14.97
# 721651                                    Security Guards   1330.0   13.83
# 721653   Food Preparation and Serving Related Occupations   3580.0   13.52
#
#          a_mean h_median a_median annual    year wage_bin
# 0       50400.0    20.97    43618    NaN  1997.0    20-25
# 1       43350.0    19.29    40123    NaN  1997.0    20-25
# 2       39660.0    15.99    33259    NaN  1997.0    15-20
# 3       49420.0    21.52    44762    NaN  1997.0    20-25
# 4       43650.0    19.32    40186    NaN  1997.0    20-25
# ...         ...      ...      ...    ...     ...      ...
# 721644  30220.0    13.37   27,800    NaN  2019.0    10-15
# 721645  25250.0    11.90   24,760    NaN  2019.0    10-15
# 721646  31150.0    14.13   29,390    NaN  2019.0    10-15
# 721651  28770.0    12.20   25,370    NaN  2019.0    10-15
# 721653  28120.0    11.89   24,730    NaN  2019.0    10-15
#
# [70882 rows x 12 columns]

# %%
# taking total employment only
emp_pro_bin = temp_emp_pro_bin['tot_emp'].sum()

# %% [markdown]
# ##### plotting by wagebin, by state

# %%
state = state_interest[0]
# temp_bin = bin_name.copy()
temp_bin = ['5-10', '10-15', '15-20', '20-25','25-30','30-35']
# temp_bin = temp_bin[1]
fig2, ax2 = plt.subplots(figsize=(11,8.5))

df1 = wage_df.copy()
df2 = lab_df.copy()

df1 = df1[wage_df['State'] == state]
df2 = lab_df[lab_df['states'] == state]

for bin in temp_bin:
    df3 = emp_pro_bin.copy()
    df3 = df3.loc[(state, bin)]
    df3.plot(ax=ax2, label=f'${bin} tot_employment per 10,000', title=f'{state}')
ax2.legend();
